# %%
import pandas as pd
import numpy as np
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
benin = pd.read_csv("C:/Users/HP/10 Acadamy PRojects/New folder/Solar-Challenge-week0/data/cleaned/solar-measurements_benin-malanville_cleaned.csv")
sierra = pd.read_csv("C:/Users/HP/10 Acadamy PRojects/New folder/Solar-Challenge-week0/data/cleaned/solar-measurements_sierraleone-bumbuna_cleaned.csv")
togo = pd.read_csv("C:/Users/HP/10 Acadamy PRojects/New folder/Solar-Challenge-week0/data/cleaned/solar-measurements_togo-dapaong_qc.csv")


# Add country column
benin['Country'] = 'Benin'
sierra['Country'] = 'Sierra Leone'
togo['Country'] = 'Togo'

# Combine them
df_all = pd.concat([benin, sierra, togo])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_24412\3909404213.py:1: DtypeWarning: Columns (6,7,10,11,12,13,14,15,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   benin = pd.read_csv("C:/Users/HP/10 Acadamy PRojects/New folder/Solar-Challenge-week0/data/cleaned/solar-measurements_benin-malanville_cleaned.csv")
# C:\Users\HP\AppData\Local\Temp\ipykernel_24412\3909404213.py:2: DtypeWarning: Columns (6,7,10,11,12,13,14,15,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   sierra = pd.read_csv("C:/Users/HP/10 Acadamy PRojects/New folder/Solar-Challenge-week0/data/cleaned/solar-measurements_sierraleone-bumbuna_cleaned.csv")
# C:\Users\HP\AppData\Local\Temp\ipykernel_24412\3909404213.py:3: DtypeWarning: Columns (6,7,10,11,12,13,14,15,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
metrics = ['GHI', 'DNI', 'DHI']
for metric in metrics:
    plt.figure(figsize=(8,4))
    sns.boxplot(x='Country', y=metric, data=df_all)
    plt.title(f"{metric} by Country")
    plt.show()

# %%
summary = df_all.groupby("Country")[['GHI', 'DNI', 'DHI']].agg(['mean', 'median', 'std']).round(2)
summary
# Out:
#                  GHI                    DNI                    DHI         \
#                 mean median     std    mean median     std    mean median
# Country
# Benin         201.96    0.3  298.49  116.38   -0.1  218.65  113.72   -0.1
# Sierra Leone  201.96    0.3  298.49  116.38   -0.1  218.65  113.72   -0.1
# Togo          230.55    2.1  322.53  151.26    0.0  250.96  116.44    2.5
#
#
#                  std
# Country
# Benin         158.95
# Sierra Leone  158.95
# Togo          156.52
